# %% [markdown]
# ### Notebook Imports and Packages

# %%
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline

# %% [markdown]
# ### Example 1 - a simple cost function:
# #### $$f(x) = x^2 + x + 1$$

# %%
def f(x):
    return x**2 + x + 2

# %%
# linspace - start number, end number, output of between numbers with equal distances 
x_1 = np.linspace(start=-3, stop=3, num=500)
#print(x_1)

# %%
# Plot the linespace data
plt.plot(x_1, f(x_1))

#style plot
plt.xlim(-4,4)
plt.ylim(0,15)
plt.xlabel('x', fontsize=16)
plt.ylabel('f(x)', fontsize=16)

plt.show()

# %% [markdown]
# ### Slope and Derivaties
# Function for the derivateive od f(x) called df(x)

# %%
def df(x):
    return 2 * x + 1

# %%
# Plot the linespace data and derivative side by side

plt.figure(figsize=[16,5])

# Chart: Cost function
plt.subplot(1, 2, 1)
plt.plot(x_1, f(x_1))

#style plot
plt.xlim(-4,4)
plt.ylim(0,15)
plt.title('Cost function', fontsize=17)
plt.xlabel('x', fontsize=16)
plt.ylabel('f(x)', fontsize=16)
plt.grid()


# Chartderivative 
plt.subplot(1, 2, 2)
plt.plot(x_1, df(x_1), c='skyblue', linewidth=5)

#style plot
plt.xlim(-4,4)
plt.ylim(-6,8)
plt.title('Slope of the Cost function', fontsize=17)
plt.xlabel('x', fontsize=16)
plt.ylabel('df(x)', fontsize=16)
plt.grid()


plt.show()

# %% [markdown]
# ### PYthon Loops & Gradiend Descent

# %%
# PYthon For Loop
for i in range(3):
        print("Hello World", i)
# Out:
# Hello World 0
# Hello World 1
# Hello World 2

# %%
# Python while loop
counter =  0
while counter < 3:
    print("Counting... ", counter)
    counter = counter + 1
print("The End")
# Out:
# Counting...  0
# Counting...  1
# Counting...  2
# The End

# %%
# Gradient Descent
new_x = 2
old_x = 0
step_multiplier = 0.1
precision = 0.0001

x_list = [new_x]
slope_list = [df(new_x)]

for i in range (130):
    old_x = new_x
    gradient = df(old_x)
    new_x = old_x - step_multiplier * gradient    
    
    x_list.append(new_x)
    slope_list.append(df(new_x))
    
    step_size = abs(new_x - old_x)
    #print(step_size)
    
    
    if step_size < precision:
        print("Precision met at loop number:", i)
        break

print('Local minimum occurs at:', new_x)
print('Slope or df(x) value at this point is:', df(new_x))
print('Cost or f(x) value at this point is:', f(new_x))
# Out:
# Precision met at loop number: 39
# Local minimum occurs at: -0.4996676930010538
# Slope or df(x) value at this point is: 0.0006646139978924159
# Cost or f(x) value at this point is: 1.7500001104279415

# %%
# Superimpose gradient descent calculations on plot

plt.figure(figsize=[16,5])

# Chart: Cost function
plt.subplot(1, 2, 1)
plt.plot(x_1, f(x_1), alpha=0.6)

x_array = np.array(x_list)
plt.scatter(x_list, f(x_array), color="red", s=100, alpha=0.4)

#style plot
plt.xlim(-4,4)
plt.ylim(0,15)
plt.title('Cost function', fontsize=17)
plt.xlabel('x', fontsize=16)
plt.ylabel('f(x)', fontsize=16)
plt.grid()


# Chart derivative 
plt.subplot(1, 2, 2)
plt.plot(x_1, df(x_1), c='skyblue', linewidth=5, alpha=0.4)

x_array = np.array(x_list)
plt.scatter(x_list, slope_list, color="red", s=100, alpha=0.6)


#style plot
plt.xlim(-4,4)
plt.ylim(-6,8)
plt.title('Slope of the Cost function', fontsize=17)
plt.xlabel('x', fontsize=16)
plt.ylabel('df(x)', fontsize=16)
plt.grid()


plt.show()

# %%
#TEST udemy
num_bottles = 99
output = []
for i in range (num_bottles):
    current_num = num_bottles - i
    current_num_down = current_num-1
    str1= "%s bottles of beer on the wall, %s bottles of beer." %(current_num,current_num)
    str2='Take one down and pass it around, %s bottles of beer on the wall.' %(current_num_down)
    str3= ''

    output.append(str1)
    output.append(str2)
    output.append(str3)
#print(output)

# %% [markdown]
# ### Multiple Minima vs initial Guess & Advanced functions
#
# #### $$g(x) = x^4 - 4x^2 + 5$$
# #### $$dg(x) = 4x^3 - 8x$$

# %%
# andom data
x_2 = np.linspace(-2, 2, 1000)

#g(x)
def g(x):
    return x**4 - 4 * x**2 + 5

def dg(x):
    return 4 * x**3 - 8 * x

# %%
# Superimpose gradient descent calculations on plot

plt.figure(figsize=[16,5])

# Chart: Cost function
plt.subplot(1, 2, 1)
plt.plot(x_2, g(x_2), alpha=0.6)

x_array = np.array(x_list)
plt.scatter(x_list, g(x_array), color="red", s=100, alpha=0.4)

#style plot
plt.xlim(-3,3)
plt.ylim(0,6)
plt.title('Cost function', fontsize=17)
plt.xlabel('x', fontsize=16)
plt.ylabel('g(x)', fontsize=16)
plt.grid()


# Chart derivative 
plt.subplot(1, 2, 2)
plt.plot(x_2, dg(x_2), c='skyblue', linewidth=5, alpha=0.4)



#style plot
plt.xlim(-3,3)
plt.ylim(-18,18)
plt.title('Slope of the Cost function', fontsize=17)
plt.xlabel('x', fontsize=16)
plt.ylabel('dg(x)', fontsize=16)
plt.grid()


plt.show()

# %% [markdown]
# ### Gradient Descent as a Python Function

# %%
def gradient_descent(derivitive_func, initial_guess, multiplier, precision):
    



new_x = 2
old_x = 0
step_multiplier = 0.1
precision = 0.0001

x_list = [new_x]
slope_list = [df(new_x)]

for i in range (130):
    old_x = new_x
    gradient = df(old_x)
    new_x = old_x - step_multiplier * gradient    
    
    x_list.append(new_x)
    slope_list.append(df(new_x))
    
    step_size = abs(new_x - old_x)
    #print(step_size)
    
    
    if step_size < precision:
        print("Precision met at loop number:", i)
        break

print('Local minimum occurs at:', new_x)
print('Slope or df(x) value at this point is:', df(new_x))
print('Cost or f(x) value at this point is:', f(new_x))
# Out:
# Precision met at loop number: 39
# Local minimum occurs at: -0.4996676930010538
# Slope or df(x) value at this point is: 0.0006646139978924159
# Cost or f(x) value at this point is: 1.7500001104279415
